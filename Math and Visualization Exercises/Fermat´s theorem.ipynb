# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ints = np.arange(1,101)

Z = np.zeros((len(ints),len(ints)))

for x in ints:
    for y in ints:
        Z[x-1,y-1] = (x**3 + y**3)**(1/3)

# %%
zInts = Z%1 == 0

fig,ax = plt.subplots(1,2,figsize=(8,6))

p1 = ax[0].imshow(Z)
ax[0].set_xlabel('y')
ax[0].set_ylabel('x')
ax[0].set_xlabel('y')
ax[0].set_title('$z = \\sqrt[3]{x^3+y^3}$',fontsize=14)
fig.colorbar(a,ax=ax[0],shrink=.5)

p2 = ax[1].imshow(zInts)
ax[1].set_xlabel('y')
ax[1].set_ylabel('x')
ax[1].set_title('Wheter $z$ is an integer',fontsize=14)
fig.colorbar(a,ax=ax[1],shrink=.5)
plt.show()

# %%
ints = np.arange(1,101)

Z = np.zeros((len(ints),len(ints)))

for x in ints:
    for y in ints:
        Z[x-1,y-1] = (x**2 + y**2)**(1/2)

# %%
zInts = Z%1 == 0

fig,ax = plt.subplots(1,2,figsize=(8,6))

p1 = ax[0].imshow(Z)
ax[0].set_xlabel('y')
ax[0].set_ylabel('x')
ax[0].set_xlabel('y')
ax[0].set_title('$z = \\sqrt{x^2+y^2}$',fontsize=14)
fig.colorbar(a,ax=ax[0],shrink=.5)

p2 = ax[1].imshow(zInts)
ax[1].set_xlabel('y')
ax[1].set_ylabel('x')
ax[1].set_title('Wheter $z$ is an integer',fontsize=14)
fig.colorbar(a,ax=ax[1],shrink=.5)
plt.show()
