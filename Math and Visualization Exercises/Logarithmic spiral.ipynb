# %%
import  numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0,10*np.pi,1000)
k = -3

x = np.cos(t) * np.exp(t/k)
y = np.sin(t) * np.exp(t/k)

plt.plot(x,y,'m',linewidth=2)
plt.axis('square')
plt.axis('off')
plt.show()

# %%
N = 150
k = np.linspace(-6,-2,N)

for i in range(N):
    x = np.cos(t) * np.exp(t/k[i])
    y = np.sin(t) * np.exp(t/k[i])
    plt.plot(x,y,color=[0,i/N,i/N])
    
plt.axis('square')
plt.axis('off')
plt.show()

# %%
# xn+1 = rxn(1-xn)
# %matplotlib

rs = np.linspace(1,4,2000)
N = 500
x = .5 + np.zeros(N)
endcap = np.arange(round(N*.9),N)

for ri in range(len(rs)):

    for i in range(N-1):
        x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
        
    u = np.unique(x[endcap])
    r = rs[ri]*np.ones(len(u))
    plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
    
plt.show()
# Out:
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# ...
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: overflow encountered in double_scalars
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:12: RuntimeWarning: invalid value encountered in sin
#   x[i+1] = rs[ri]*x[i]*(1-x[i]) + .2*np.sin(2*np.pi*x[i])**2
# C:\Users\Milo\AppData\Local\Temp/ipykernel_4244/903154092.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(r,u,'k.',markersize=1,color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])
