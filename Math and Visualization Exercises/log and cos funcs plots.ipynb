# %%
import sympy as sym
import numpy as np
import matplotlib.pyplot as plt

# %%
x = sym.symbols('x')
x = np. linspace(2,20,100)
y = np.log(x)
plt.plot(x,y,'r')
plt.show()

# %%
x = sym.symbols('x')
x = np. linspace(2,6,100)
y = np.cos(x)
plt.plot(x,y,'r')
plt.show()
