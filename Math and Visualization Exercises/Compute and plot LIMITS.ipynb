# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt
from IPython.display import display,Math

# %%
x = sym.symbols('x')

fx = x**3

lim_pnt = 1.5
lim = sym.limit(fx,x,lim_pnt)
lim
display(Math('\\lim_{x\\to %g} %s = %g'%(lim_pnt,sym.latex(fx),lim)))
# Out:
# $\displaystyle \lim_{x\to 1.5} x^{3} = 3.375$

# %%
fxx = sym.lambdify(x,fx)
xx = np.linspace(-5,5,100)
plt.plot(xx,fxx(xx))
plt.plot(lim_pnt,lim,'ro')

# %%
fx = (x**2)/(x-2)
fxx = sym.lambdify(x,fx)
xx = np.linspace(1,3,102)

lim_pnt = 2
lim = sym.limit(fx,x,lim_pnt,dir='-')
plt.plot(xx,fxx(xx))

display(Math('\\lim_{x\\to %g^-} %s = %g'%(lim_pnt,sym.latex(fx),lim)))
# Out:
# $\displaystyle \lim_{x\to 2^-} \frac{x^{2}}{x - 2} = -inf$

# %%
x = sym.symbols('x')

fx = sym.exp(-x) * sym.sqrt( x + 1 )
gx = sym.cos( x + sym.sin(x) )

fxx = sym.lambdify(x,fx)
gxx = sym.lambdify(x,gx)
xx = np.linspace(0,4*np.pi,100)

# Compute the limits
lim_pnt = 5
lim_fx = sym.limit(fx,x,lim_pnt)
lim_gx = sym.limit(gx,x,lim_pnt)

# Plot the functions
plt.plot(xx,fxx(xx),label='f(x)')
plt.plot(lim_pnt,limfx,'ro')

# PLot the limits
plt.plot(xx,gxx(xx),label='g(x)')
plt.plot(lim_pnt,limgx,'ro')

plt.legend()
plt.show()

# Division of limits property
fxgx_div = fx/gx
lim_fgx = sym.limit(fxgx_div,x,lim_pnt)

display(Math('\\frac{\\lim_{x\\to %g}f(x)}{\\lim_{x\\to %g}g(x)} \
             = \\lim_{x\\to %g}\\frac{f(x)}{g(x)}'%(lim_pnt,lim_pnt,lim_pnt)))
display(Math('\\lim_{x\\to %g}\\frac{f(x)}{g(x)} = %g'%(lim_pnt,lim_fx/lim_gx)))

display(Math('\\frac{\\lim_{x\\to %g}f(x)}{\\lim_{x\\to %g}g(x)} \
             = \\frac{%g}{%g} = %g'%(lim_pnt,lim_pnt,lim_fx,lim_gx,lim_fgx)))
# Out:
# $\displaystyle \frac{\lim_{x\to 5}f(x)}{\lim_{x\to 5}g(x)}              = \lim_{x\to 5}\frac{f(x)}{g(x)}$
# $\displaystyle \lim_{x\to 5}\frac{f(x)}{g(x)} = -0.026534$
# $\displaystyle \frac{\lim_{x\to 5}f(x)}{\lim_{x\to 5}g(x)}              = \frac{0.0165045}{-0.622015} = -0.026534$

# %%
np.exp(1)
# Out:
# 2.718281828459045
